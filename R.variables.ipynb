# %%
age<-24

# %%
marks1<-10

# %%
subject_java<-20

# %%
x<-10

# %%
typeof(x)
# Out:
# [1] "double"

# %%
mode(x)
# Out:
# [1] "numeric"

# %%
storage.mode(x)
# Out:
# [1] "double"

# %%
class(x)
# Out:
# [1] "numeric"

# %%
x<-10.75

# %%
class(x)
# Out:
# [1] "numeric"

# %%
x<-'Hello'

# %%
class(x)
# Out:
# [1] "character"

# %%
x<-TRUE

# %%
class(x)
# Out:
# [1] "logical"
